# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df_apps = pd.read_csv('apps.csv')

# %%
df_apps.shape
# Out:
# (10841, 12)

# %%
df_apps.drop(['Last_Updated', 'Android_Ver'], axis=1, inplace=True)

# %%
print(df_apps.columns.tolist())
# Out:
# ['App', 'Category', 'Rating', 'Reviews', 'Size_MBs', 'Installs', 'Type', 'Price', 'Content_Rating', 'Genres']

# %%
df_apps.head()
# Out:
#                                             App         Category  Rating  \
# 0                       Ak Parti Yardım Toplama           SOCIAL     NaN
# 1                    Ain Arabic Kids Alif Ba ta           FAMILY     NaN
# 2  Popsicle Launcher for Android P 9.0 launcher  PERSONALIZATION     NaN
# 3                     Command & Conquer: Rivals           FAMILY     NaN
# 4                                    CX Network         BUSINESS     NaN
#
#    Reviews  Size_MBs Installs  Type   Price Content_Rating           Genres
# 0        0       8.7        0  Paid  $13.99           Teen           Social
# 1        0      33.0        0  Paid   $2.99       Everyone        Education
# 2        0       5.5        0  Paid   $1.49       Everyone  Personalization
# 3        0      19.0        0   NaN       0   Everyone 10+         Strategy
# 4        0      10.0        0  Free       0       Everyone         Business

# %%
df_apps_clean = df_apps.dropna()
df_apps_clean.shape
# Out:
# (9367, 10)

# %%
df_apps_clean.head()
# Out:
#                                                 App Category  Rating  Reviews  \
# 21                              KBA-EZ Health Guide  MEDICAL     5.0        4
# 28                                         Ra Ga Ba     GAME     5.0        2
# 47                                          Mu.F.O.     GAME     5.0        2
# 82                                 Brick Breaker BR     GAME     5.0        7
# 99  Anatomy & Physiology Vocabulary Exam Review App  MEDICAL     5.0        1
#
#     Size_MBs Installs  Type  Price Content_Rating   Genres
# 21      25.0        1  Free      0       Everyone  Medical
# 28      20.0        1  Paid  $1.49       Everyone   Arcade
# 47      16.0        1  Paid  $0.99       Everyone   Arcade
# 82      19.0        5  Free      0       Everyone   Arcade
# 99       4.6        5  Free      0       Everyone  Medical

# %%
duplicated_rows = df_apps_clean[df_apps_clean.duplicated()]
print(duplicated_rows.shape)
duplicated_rows.head()
# Out:
# (476, 10)
#                                              App Category  Rating  Reviews  \
# 946                       420 BZ Budeze Delivery  MEDICAL     5.0        2
# 1133                                 MouseMingle   DATING     2.7        3
# 1196  Cardiac diagnosis (heart rate, arrhythmia)  MEDICAL     4.4        8
# 1231                                Sway Medical  MEDICAL     5.0        3
# 1247              Chat Kids - Chat Room For Kids   DATING     4.7        6
#
#       Size_MBs Installs  Type   Price Content_Rating   Genres
# 946       11.0      100  Free       0     Mature 17+  Medical
# 1133       3.9      100  Free       0     Mature 17+   Dating
# 1196       6.5      100  Paid  $12.99       Everyone  Medical
# 1231      22.0      100  Free       0       Everyone  Medical
# 1247       4.9      100  Free       0     Mature 17+   Dating

# %%
df_apps_clean = df_apps_clean.drop_duplicates()

# %%
duplicated_rows = df_apps_clean[df_apps_clean.duplicated()]
print(duplicated_rows.shape)
duplicated_rows.head()
# Out:
# (0, 10)
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size_MBs, Installs, Type, Price, Content_Rating, Genres]
# Index: []

# %%
df_apps_clean = df_apps_clean.sort_values('Reviews', ascending=False).drop_duplicates(subset=['App'], keep='first')

# %%
df_apps_clean.shape
# Out:
# (8182, 11)

# %%
df_apps_clean.sort_values('Rating', ascending=False).head()
# Out:
#                                      App            Category  Rating  Reviews  \
# 425                       Labs on Demand             MEDICAL     5.0        1
# 1666  DM Buddy » Learn Digital Marketing              FAMILY     5.0        3
# 979                NOMISMA.com.cy by FMW  NEWS_AND_MAGAZINES     5.0        3
# 906                        Propel BI APP            BUSINESS     5.0        3
# 382   DG OFF - 100% Free Coupons & Deals            SHOPPING     5.0        1
#
#       Size_MBs  Installs  Type  Price Content_Rating            Genres  \
# 425       22.0        10  Free    0.0       Everyone           Medical
# 1666       1.7       500  Free    0.0       Everyone         Education
# 979        6.3       100  Free    0.0       Everyone  News & Magazines
# 906       23.0       100  Free    0.0       Everyone          Business
# 382        1.1        10  Free    0.0       Everyone          Shopping
#
#       Revenue_Estimate
# 425                0.0
# 1666               0.0
# 979                0.0
# 906                0.0
# 382                0.0

# %%
df_apps_clean.sort_values('Size_MBs', ascending=False).head()
# Out:
#                                     App            Category  Rating  Reviews  \
# 9942     Talking Babsy Baby: Baby Games           LIFESTYLE     4.0   140995
# 1795               Navi Radiography Pro             MEDICAL     4.7       11
# 3144                         Vi Trainer  HEALTH_AND_FITNESS     3.6      124
# 8719         Draft Simulator for FUT 18              SPORTS     4.6   162933
# 8718  Mini Golf King - Multiplayer Game                GAME     4.5   531458
#
#       Size_MBs  Installs  Type  Price Content_Rating                  Genres  \
# 9942     100.0  10000000  Free   0.00       Everyone  Lifestyle;Pretend Play
# 1795     100.0       500  Paid  15.99       Everyone                 Medical
# 3144     100.0      5000  Free   0.00       Everyone        Health & Fitness
# 8719     100.0   5000000  Free   0.00       Everyone                  Sports
# 8718     100.0   5000000  Free   0.00       Everyone                  Sports
#
#       Revenue_Estimate
# 9942               0.0
# 1795            7995.0
# 3144               0.0
# 8719               0.0
# 8718               0.0

# %%
df_apps_clean.sort_values('Reviews', ascending=False).head(50)
# Out:
#                                                      App            Category  \
# 10805                                           Facebook              SOCIAL
# 10785                                 WhatsApp Messenger       COMMUNICATION
# 10808                                          Instagram              SOCIAL
# 10790           Messenger – Text and Video Chat for Free       COMMUNICATION
# 10652                                     Clash of Clans                GAME
# 10744            Clean Master- Space Cleaner & Antivirus               TOOLS
# 10838                                     Subway Surfers                GAME
# 10828                                            YouTube       VIDEO_PLAYERS
# 10746  Security Master - Antivirus, VPN, AppLock, Boo...               TOOLS
# 10588                                       Clash Royale                GAME
# 10767                                   Candy Crush Saga                GAME
# 10771        UC Browser - Fast Download Private & Secure       COMMUNICATION
# 10737                                           Snapchat              SOCIAL
# 10489    360 Security - Free Antivirus, Booster, Cleaner               TOOLS
# 10732                                     My Talking Tom                GAME
# 10599                                        8 Ball Pool                GAME
# 10302  DU Battery Saver - Battery Charger & Battery Life               TOOLS
# 10371                        BBM - Free Calls & Messages       COMMUNICATION
# 10550  Cache Cleaner-DU Speed Booster (booster & clea...               TOOLS
# 10757                                            Twitter  NEWS_AND_MAGAZINES
# 10730                                    Viber Messenger       COMMUNICATION
# 10579                                     Shadow Fight 2                GAME
# 10815                                      Google Photos         PHOTOGRAPHY
# 10724                        LINE: Free Calls & Messages       COMMUNICATION
# 10719                                                Pou                GAME
# 10792                      Skype - free IM & video calls       COMMUNICATION
# 10628                                         Pokémon GO                GAME
# 10409           Minion Rush: Despicable Me Official Game              FAMILY
# 10694                                            Yes day                GAME
# Mature 17+          357
# Everyone 10+        305
# Adults only 18+       3
# Unrated               1
# Name: count, dtype: int64

# %%
fig = px.pie(ratings, values=ratings.values, names=ratings.index)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="866cfd6a-bf0e-4a49-a898-a10b897818cd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("866cfd6a-bf0e-4a49-a898-a10b897818cd")) {                    Plotly.newPlot(                        "866cfd6a-bf0e-4a49-a898-a10b897818cd",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Content_Rating=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Everyone","Teen","Mature 17+","Everyone 10+","Adults only 18+","Unrated"],"legendgroup":"","name":"","showlegend":true,"values":[6605,911,357,305,3,1],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","m ...

# %%
fig = px.pie(labels=ratings.index, values=ratings.values, title="Content Rating", names=ratings.index, hole=0.5)
fig.update_traces(textposition='outside', textinfo='percent+label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="47f43f41-4040-41da-8f6d-f731f76e6bb3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("47f43f41-4040-41da-8f6d-f731f76e6bb3")) {                    Plotly.newPlot(                        "47f43f41-4040-41da-8f6d-f731f76e6bb3",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.5,"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Everyone","Teen","Mature 17+","Everyone 10+","Adults only 18+","Unrated"],"legendgroup":"","name":"","showlegend":true,"values":[6605,911,357,305,3,1],"type":"pie","textinfo":"percent+label","textposition":"outside"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"t ...

# %%
df_apps_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8182 entries, 10805 to 151
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   App               8182 non-null   object
#  1   Category          8182 non-null   object
#  2   Rating            8182 non-null   float64
#  3   Reviews           8182 non-null   int64
#  4   Size_MBs          8182 non-null   float64
#  5   Installs          8182 non-null   int64
#  6   Type              8182 non-null   object
#  7   Price             8182 non-null   float64
#  8   Content_Rating    8182 non-null   object
#  9   Genres            8182 non-null   object
#  10  Revenue_Estimate  8182 non-null   float64
# dtypes: float64(4), int64(2), object(5)
# memory usage: 767.1+ KB

# %%
df_apps_clean.Installs = df_apps_clean.Installs.astype(str).str.replace(',', "")
df_apps_clean.Installs = pd.to_numeric(df_apps_clean.Installs)
df_apps_clean[['App', 'Installs']].groupby('Installs').count()
# Out:
#              App
# Installs
# 1              3
# 5              9
# 10            69
# 50            56
# 100          301
# 500          199
# 1000         693
# 5000         422
# 10000        981
# 50000        456
# 100000      1094
# 500000       503
# 1000000     1415
# 5000000      607
# 10000000     937
# 50000000     204
# 100000000    189
# 500000000     24
# 1000000000    20

# %%
df_apps_clean.Price.describe()
# Out:
# count    8182.000000
# mean        0.319807
# std         1.924685
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max        79.990000
# Name: Price, dtype: float64

# %%
df_apps_clean.Price = df_apps_clean.Price.astype(str).str.replace('$', "")
df_apps_clean.Price = pd.to_numeric(df_apps_clean.Price)

df_apps_clean.sort_values('Price', ascending=False).head(20)
# Out:
#                                                     App     Category  Rating  \
# 2281                          Vargo Anesthesia Mega App      MEDICAL     4.6
# 1407                                       LTC AS Legal      MEDICAL     4.0
# 2629                                   I am Rich Person    LIFESTYLE     4.2
# 2481                            A Manual of Acupuncture      MEDICAL     3.5
# 504                           AP Art History Flashcards       FAMILY     5.0
# 2207                                           EMT PASS      MEDICAL     3.4
# 2463                                 PTA Content Master      MEDICAL     4.2
# 4264                            Golfshot Plus: Golf GPS       SPORTS     4.1
# 4774   Human Anatomy Atlas 2018: Complete 3D Human Body      MEDICAL     4.5
# 3241  Muscle Premium - Human Anatomy, Kinesiology, B...      MEDICAL     4.2
# 526                          USMLE Step 2 CK Flashcards       FAMILY     5.0
# 2119                                         NewTek NDI  PHOTOGRAPHY     3.5
# 2293                               Hospitalist Handbook      MEDICAL     4.8
# 4470                                  DRAGON QUEST VIII       FAMILY     4.5
# 2473                            boattheory.ch Full 2018       FAMILY     4.7
# 4090                             I am Rich Premium Plus      FINANCE     4.6
# 3778                            The World Ends With You         GAME     4.6
# 1508                                 SkyTest BU/GU Lite     BUSINESS     2.9
# 3439                            Trine 2: Complete Story         GAME     3.8
# 2603                         2017 EMRA Antibiotic Guide      MEDICAL     4.4
#
#       Reviews  Size_MBs  Installs  Type  Price Content_Rating        Genres  \
# 2281       92      32.0      1000  Paid  79.99       Everyone       Medical
# 1407        6       1.3       100  Paid  39.99       Everyone       Medical
# 2629      134       1.8      1000  Paid  37.99       Everyone     Lifestyle
# 2481      214      68.0      1000  Paid  33.99       Everyone       Medical
# 504         1      96.0        10  Paid  29.99     Mature 17+     Education
# 2207       51       2.4      1000  Paid  29.99       Everyone       Medical
# 2463       64      41.0      1000  Paid  29.99       Everyone       Medical
# 4264     3387      25.0     50000  Paid  29.99       Everyone        Sports
# 4774     2923      25.0    100000  Paid  24.99       Everyone       Medical
# 3241      168      25.0     10000  Paid  24.99       Everyone       Medical
# 526         1      40.0        10  Paid  19.99       Everyone     Education
# 2119       77       1.2      1000  Paid  19.99       Everyone   Photography
# 2293       12      18.0      1000  Paid  19.99       Everyone       Medical
# 4470     7812      27.0     50000  Paid  19.99   Everyone 10+  Role Playing
# 2473       54      50.0      1000  Paid  19.40       Everyone     Education
# 4090      459       2.0     10000  Paid  18.99       Everyone       Finance
# 3778     4108      13.0     10000  Paid  17.99   Everyone 10+        Arcade
# 1508       28      20.0       500  Paid  17.99       Everyone      Business
# 3439      252      11.0     10000  Paid  16.99           Teen        Action
# 2603       12       3.8      1000  Paid  16.99       Everyone       Medical
#
#       Revenue_Estimate
# 2281           79990.0
# 1407            3999.0
# 2629           37990.0
# 2481           33990.0
# 504              299.9
# 2207           29990.0
# 2463           29990.0
# 4264         1499500.0
# 4774         2499000.0
# 3241          249900.0
# 526              199.9
# 2119           19990.0
# 2293           19990.0
# 4470          999500.0
# 2473           19400.0
# 4090          189900.0
# 3778          179900.0
# 1508            8995.0
# 3439          169900.0
# 2603           16990.0

# %%
df_apps_clean = df_apps_clean[df_apps_clean['Price'] < 250]
df_apps_clean.sort_values('Price', ascending=False).head(5)
# Out:
#                             App   Category  Rating  Reviews  Size_MBs  \
# 2281  Vargo Anesthesia Mega App    MEDICAL     4.6       92      32.0
# 1407               LTC AS Legal    MEDICAL     4.0        6       1.3
# 2629           I am Rich Person  LIFESTYLE     4.2      134       1.8
# 2481    A Manual of Acupuncture    MEDICAL     3.5      214      68.0
# 504   AP Art History Flashcards     FAMILY     5.0        1      96.0
#
#       Installs  Type  Price Content_Rating     Genres  Revenue_Estimate
# 2281      1000  Paid  79.99       Everyone    Medical           79990.0
# 1407       100  Paid  39.99       Everyone    Medical            3999.0
# 2629      1000  Paid  37.99       Everyone  Lifestyle           37990.0
# 2481      1000  Paid  33.99       Everyone    Medical           33990.0
# 504         10  Paid  29.99     Mature 17+  Education             299.9

# %%
df_apps_clean['Revenue_Estimate'] = df_apps_clean.Installs.mul(df_apps_clean.Price)
df_apps_clean.sort_values('Revenue_Estimate', ascending=False)[:10]
# Out:
#                                 App     Category  Rating  Reviews   Size_MBs  \
# 9220                      Minecraft       FAMILY     4.5  2376564  19.000000
# 8825                  Hitman Sniper         GAME     4.6   408292  29.000000
# 7151  Grand Theft Auto: San Andreas         GAME     4.4   348962  26.000000
# 7977        Sleep as Android Unlock    LIFESTYLE     4.5    23966   0.851562
# 7477            Facetune - For Free  PHOTOGRAPHY     4.4    49553  48.000000
# 6594            DraStic DS Emulator         GAME     4.6    87766  12.000000
# 6082                   Weather Live      WEATHER     4.5    76593   4.750000
# 6746     Card Wars - Adventure Time       FAMILY     4.3   129603  23.000000
# 7954                    Bloons TD 5       FAMILY     4.6   190086  94.000000
# 7044                         Tasker        TOOLS     4.6    43045   3.400000
#
#       Installs  Type  Price Content_Rating                     Genres  \
# 9220  10000000  Paid   6.99   Everyone 10+  Arcade;Action & Adventure
# 8825  10000000  Paid   0.99     Mature 17+                     Action
# 7151   1000000  Paid   6.99     Mature 17+                     Action
# 7977   1000000  Paid   5.99       Everyone                  Lifestyle
# 7477   1000000  Paid   5.99       Everyone                Photography
# 6594   1000000  Paid   4.99       Everyone                     Action
# 6082    500000  Paid   5.99       Everyone                    Weather
# 6746   1000000  Paid   2.99   Everyone 10+    Card;Action & Adventure
# 7954   1000000  Paid   2.99       Everyone                   Strategy
# 7044   1000000  Paid   2.99       Everyone                      Tools
#
#       Revenue_Estimate
# 9220        69900000.0
# 8825         9900000.0
# 7151         6990000.0
# 7977         5990000.0
# 7477         5990000.0
# 6594         4990000.0
# 6082         2995000.0
# 6746         2990000.0
# 7954         2990000.0
# 7044         2990000.0

# %%
top10_category = df_apps_clean.Category.value_counts()[:10]

# %%
top10_category
# Out:
# Category
# FAMILY             1647
# GAME                898
# TOOLS               720
# PRODUCTIVITY        301
# PERSONALIZATION     298
# LIFESTYLE           297
# FINANCE             296
# MEDICAL             290
# BUSINESS            263
# PHOTOGRAPHY         263
# Name: count, dtype: int64

# %%
bar = px.bar(x = top10_category.index,  y = top10_category.values)

bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a50ac280-b506-4283-8359-a3c90c7fcaf8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a50ac280-b506-4283-8359-a3c90c7fcaf8")) {                    Plotly.newPlot(                        "a50ac280-b506-4283-8359-a3c90c7fcaf8",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["FAMILY","GAME","TOOLS","PRODUCTIVITY","PERSONALIZATION","LIFESTYLE","FINANCE","MEDICAL","BUSINESS","PHOTOGRAPHY"],"xaxis":"x","y":[1647,898,720,301,298,297,296,290,263,263],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}}," ...

# %%
category_installs = df_apps_clean.groupby('Category').agg({'Installs': pd.Series.sum})
category_installs.sort_values('Installs', ascending=True, inplace=True)

# %%
category_installs
# Out:
#                         Installs
# Category
# EVENTS                  15949410
# BEAUTY                  26916200
# PARENTING               31116110
# MEDICAL                 38252576
# COMICS                  44931100
# LIBRARIES_AND_DEMO      52083000
# AUTO_AND_VEHICLES       53129800
# HOUSE_AND_HOME          97072000
# ART_AND_DESIGN         113233100
# DATING                 140911410
# EDUCATION              188852000
# FOOD_AND_DRINK         211677750
# WEATHER                361096500
# FINANCE                455249400
# MAPS_AND_NAVIGATION    503267560
# LIFESTYLE              503611120
# BUSINESS               697018120
# ENTERTAINMENT          989660000
# SPORTS                1096431465
# HEALTH_AND_FITNESS    1144006220
# SHOPPING              1400331540
# PERSONALIZATION       1532352930
# BOOKS_AND_REFERENCE   1665791655
# NEWS_AND_MAGAZINES    2369110650
# TRAVEL_AND_LOCAL      2894859300
# VIDEO_PLAYERS         3931797200
# PHOTOGRAPHY           4658143130
# SOCIAL                5487841475
# PRODUCTIVITY          5793070180
# FAMILY                6231954490
# TOOLS                 8100724500
# COMMUNICATION        11038241530
# GAME                 13447762717
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# category_installs['Installs'].plot(kind='hist', bins=20, title='Installs')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Installs']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Installs'}, axis=1)
#               .sort_values('Installs', ascending=True))
#   xs = counted['Installs']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = category_installs.sort_values('Installs', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Installs')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# category_installs['Installs'].plot(kind='line', figsize=(8, 4), title='Installs')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
h_bar = px.bar(x = category_installs.Installs, y = category_installs.index, orientation='h')
h_bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7b2a3d29-842d-4e60-acbe-7025725f417c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7b2a3d29-842d-4e60-acbe-7025725f417c")) {                    Plotly.newPlot(                        "7b2a3d29-842d-4e60-acbe-7025725f417c",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[15949410,26916200,31116110,38252576,44931100,52083000,53129800,97072000,113233100,140911410,188852000,211677750,361096500,455249400,503267560,503611120,697018120,989660000,1096431465,1144006220,1400331540,1532352930,1665791655,2369110650,2894859300,3931797200,4658143130,5487841475,5793070180,6231954490,8100724500,11038241530,13447762717],"xaxis":"x","y":["EVENTS","BEAUTY","PARENTING","MEDICAL","COMICS","LIBRARIES_AND_DEMO","AUTO_AND_VEHICLES","HOUSE_AND_HOME","ART_AND_DESIGN","DATING","EDUCATION","FOOD_AND_DRINK","WEATHER","FINANCE","MAPS_AND_NAVIGATION","LIFESTYLE","BUSINESS","ENTERTAINMENT","SPORTS","HEALTH_AND_FITNESS","SHOPPING","PERSONALIZATION","BOOKS_AND_REFERENCE","NEWS_AND_MAGAZINES","TRAVEL_AND_LOCAL","VIDEO_PLAYERS","PHOTOGRAPHY","SOCIAL","PRODUCTIVITY","FAMILY","TOOLS","COMMUNICATION","GAME"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d ...

# %%
h_bar = px.bar(x = category_installs.Installs, y = category_installs.index, orientation='h', title='Category Popularity')

h_bar.update_layout(xaxis_title='Number of Downloads', yaxis_title='Category')
h_bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d05700f8-6b69-4fd7-8bc3-71c1ec204c32" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d05700f8-6b69-4fd7-8bc3-71c1ec204c32")) {                    Plotly.newPlot(                        "d05700f8-6b69-4fd7-8bc3-71c1ec204c32",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[15949410,26916200,31116110,38252576,44931100,52083000,53129800,97072000,113233100,140911410,188852000,211677750,361096500,455249400,503267560,503611120,697018120,989660000,1096431465,1144006220,1400331540,1532352930,1665791655,2369110650,2894859300,3931797200,4658143130,5487841475,5793070180,6231954490,8100724500,11038241530,13447762717],"xaxis":"x","y":["EVENTS","BEAUTY","PARENTING","MEDICAL","COMICS","LIBRARIES_AND_DEMO","AUTO_AND_VEHICLES","HOUSE_AND_HOME","ART_AND_DESIGN","DATING","EDUCATION","FOOD_AND_DRINK","WEATHER","FINANCE","MAPS_AND_NAVIGATION","LIFESTYLE","BUSINESS","ENTERTAINMENT","SPORTS","HEALTH_AND_FITNESS","SHOPPING","PERSONALIZATION","BOOKS_AND_REFERENCE","NEWS_AND_MAGAZINES","TRAVEL_AND_LOCAL","VIDEO_PLAYERS","PHOTOGRAPHY","SOCIAL","PRODUCTIVITY","FAMILY","TOOLS","COMMUNICATION","GAME"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d ...

# %%
cat_number = df_apps_clean.groupby('Category').agg({'App': pd.Series.count})

# %%
cat_merged_df = pd.merge(cat_number, category_installs, on='Category', how="inner")
print(f'The dimensions of the DataFrame are: {cat_merged_df.shape}')
cat_merged_df.sort_values('Installs', ascending=False)
# Out:
# The dimensions of the DataFrame are: (33, 2)
#                       App     Installs
# Category
# GAME                  898  13447762717
# COMMUNICATION         256  11038241530
# TOOLS                 720   8100724500
# FAMILY               1647   6231954490
# PRODUCTIVITY          301   5793070180
# SOCIAL                203   5487841475
# PHOTOGRAPHY           263   4658143130
# VIDEO_PLAYERS         149   3931797200
# TRAVEL_AND_LOCAL      187   2894859300
# NEWS_AND_MAGAZINES    204   2369110650
# BOOKS_AND_REFERENCE   169   1665791655
# PERSONALIZATION       298   1532352930
# SHOPPING              180   1400331540
# HEALTH_AND_FITNESS    244   1144006220
# SPORTS                260   1096431465
# ENTERTAINMENT          87    989660000
# BUSINESS              263    697018120
# LIFESTYLE             297    503611120
# MAPS_AND_NAVIGATION   118    503267560
# FINANCE               296    455249400
# WEATHER                72    361096500
# FOOD_AND_DRINK         94    211677750
# EDUCATION             105    188852000
# DATING                133    140911410
# ART_AND_DESIGN         59    113233100
# HOUSE_AND_HOME         61     97072000
# AUTO_AND_VEHICLES      73     53129800
# LIBRARIES_AND_DEMO     64     52083000
# COMICS                 54     44931100
# MEDICAL               290     38252576
# PARENTING              50     31116110
# BEAUTY                 42     26916200
# EVENTS                 45     15949410

# %%
scatter = px.scatter(cat_merged_df, x='App',  y='Installs', title='Category Concentration', size='App', hover_name=cat_merged_df.index, color='Installs')

scatter.update_layout(xaxis_title="Number of Apps (Lower=More Concentrated)", yaxis_title="Installs", yaxis=dict(type='log'))

scatter.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7a6fe205-5987-44b9-8858-ed746df213c0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7a6fe205-5987-44b9-8858-ed746df213c0")) {                    Plotly.newPlot(                        "7a6fe205-5987-44b9-8858-ed746df213c0",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eApp=%{marker.size}\u003cbr\u003eInstalls=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["ART_AND_DESIGN","AUTO_AND_VEHICLES","BEAUTY","BOOKS_AND_REFERENCE","BUSINESS","COMICS","COMMUNICATION","DATING","EDUCATION","ENTERTAINMENT","EVENTS","FAMILY","FINANCE","FOOD_AND_DRINK","GAME","HEALTH_AND_FITNESS","HOUSE_AND_HOME","LIBRARIES_AND_DEMO","LIFESTYLE","MAPS_AND_NAVIGATION","MEDICAL","NEWS_AND_MAGAZINES","PARENTING","PERSONALIZATION","PHOTOGRAPHY","PRODUCTIVITY","SHOPPING","SOCIAL","SPORTS","TOOLS","TRAVEL_AND_LOCAL","VIDEO_PLAYERS","WEATHER"],"legendgroup":"","marker":{"color":[113233100,53129800,26916200,1665791655,697018120,44931100,11038241530,140911410,188852000,989660000,15949410,6231954490,455249400,211677750,13447762717,1144006220,97072000,52083000,503611120,503267560,38252576,2369110650,31116110,1532352930,4658143130,5793070180,1400331540,5487841475,1096431465,8100724500,2894859300,3931797200,361096500],"coloraxis":"coloraxis","size":[59,73,42,169,263,54,256,133,105,87,45,1647,296,94,898,244,61,64,297,118,290,204,50,298,263,301,180,203,260,720,187,149,72],"sizemode":"area","sizeref":4.1175,"symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[59,73,42,169,263,54,256,133,105,87,45,1647,296,94,898,244,61,64,297,118,290,204,50,298,263,301,180,203,260,720,187,149,72],"xaxis":"x","y":[113233100,53129800,26916200,1665791655,697018120,44931100,11038241530,140911410,188852000,989660000,15949410,6231954490,455249400,211677750,13447762717,1144006220,97072000,52083000,503611120,503267560,38252576,2369110650,31116110,1532352930,4658143130,5793070180,1400331540,5487841475,1096431465,8100724500,2894859300,3931797200,361096500],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0, ...

# %%
len (df_apps_clean.Genres.unique())
# Out:
# 114

# %%
df_apps_clean.Genres.value_counts().sort_values (ascending=True) [:5]
# Out:
# Genres
# Comics;Creativity                      1
# Board;Pretend Play                     1
# Health & Fitness;Education             1
# Casual;Music & Video                   1
# Health & Fitness;Action & Adventure    1
# Name: count, dtype: int64

# %%
stack = df_apps_clean.Genres.str.split(';', expand=True).stack()
print(f'We now have a single column with shape: {stack.shape}')
num_genres = stack.value_counts()
print(f'Number of genres: {len(num_genres)}')
# Out:
# We now have a single column with shape: (8560,)
# Number of genres: 53

# %%
bar = px.bar(x = num_genres.index[:15], y = num_genres.values[:15], title='Top Genres', hover_name=num_genres.index[:15], color=num_genres.values[:15], color_continuous_scale='Agsunset')
bar.update_layout(xaxis_title='Genre', yaxis_title='Number of Apps', coloraxis_showscale=False)
bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e565b0c8-f274-4f41-8feb-dc97f7d8006f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e565b0c8-f274-4f41-8feb-dc97f7d8006f")) {                    Plotly.newPlot(                        "e565b0c8-f274-4f41-8feb-dc97f7d8006f",                        [{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003ecolor=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Tools","Education","Entertainment","Action","Productivity","Lifestyle","Personalization","Finance","Medical","Sports","Photography","Business","Communication","Health & Fitness","Casual"],"legendgroup":"","marker":{"color":[720,587,498,304,301,298,298,296,290,270,263,263,257,246,217],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Tools","Education","Entertainment","Action","Productivity","Lifestyle","Personalization","Finance","Medical","Sports","Photography","Business","Communication","Health & Fitness","Casual"],"xaxis":"x","y":[720,587,498,304,301,298,298,296,290,270,263,263,257,246,217],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outl ...

# %%
df_apps_clean.Type.value_counts()
# Out:
# Type
# Free    7595
# Paid     587
# Name: count, dtype: int64

# %%
df_free_vs_paid = df_apps_clean.groupby(["Category", "Type"], as_index=False).agg({'App': pd.Series.count})
df_free_vs_paid.head()
# Out:
#             Category  Type  App
# 0     ART_AND_DESIGN  Free   56
# 1     ART_AND_DESIGN  Paid    3
# 2  AUTO_AND_VEHICLES  Free   72
# 3  AUTO_AND_VEHICLES  Paid    1
# 4             BEAUTY  Free   42

# %%
g_bar = px.bar(df_free_vs_paid,  x='Category', y='App', title='Free vs Paid Apps by Category', color='Type', barmode='group')
g_bar.update_layout(xaxis_title='Category', yaxis_title='Number of Apps', xaxis={'categoryorder':'total descending'}, yaxis=dict(type='log'))
g_bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="30efba5c-1a5a-4eaf-a329-1c6be9e3724b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("30efba5c-1a5a-4eaf-a329-1c6be9e3724b")) {                    Plotly.newPlot(                        "30efba5c-1a5a-4eaf-a329-1c6be9e3724b",                        [{"alignmentgroup":"True","hovertemplate":"Type=Free\u003cbr\u003eCategory=%{x}\u003cbr\u003eApp=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Free","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Free","offsetgroup":"Free","orientation":"v","showlegend":true,"textposition":"auto","x":["ART_AND_DESIGN","AUTO_AND_VEHICLES","BEAUTY","BOOKS_AND_REFERENCE","BUSINESS","COMICS","COMMUNICATION","DATING","EDUCATION","ENTERTAINMENT","EVENTS","FAMILY","FINANCE","FOOD_AND_DRINK","GAME","HEALTH_AND_FITNESS","HOUSE_AND_HOME","LIBRARIES_AND_DEMO","LIFESTYLE","MAPS_AND_NAVIGATION","MEDICAL","NEWS_AND_MAGAZINES","PARENTING","PERSONALIZATION","PHOTOGRAPHY","PRODUCTIVITY","SHOPPING","SOCIAL","SPORTS","TOOLS","TRAVEL_AND_LOCAL","VIDEO_PLAYERS","WEATHER"],"xaxis":"x","y":[56,72,42,161,254,54,234,131,102,85,45,1496,289,92,822,233,61,64,284,113,228,202,48,233,248,283,178,201,238,657,179,145,65],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Type=Paid\u003cbr\u003eCategory=%{x}\u003cbr\u003eApp=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Paid","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Paid","offsetgroup":"Paid","orientation":"v","showlegend":true,"textposition":"auto","x":["ART_AND_DESIGN","AUTO_AND_VEHICLES","BOOKS_AND_REFERENCE","BUSINESS","COMMUNICATION","DATING","EDUCATION","ENTERTAINMENT","FAMILY","FINANCE","FOOD_AND_DRINK","GAME","HEALTH_AND_FITNESS","LIFESTYLE","MAPS_AND_NAVIGATION","MEDICAL","NEWS_AND_MAGAZINES","PARENTING","PERSONALIZATION","PHOTOGRAPHY","PRODUCTIVITY","SHOPPING","SOCIAL","SPORTS","TOOLS","TRAVEL_AND_LOCAL","VIDEO_PLAYERS","WEATHER"],"xaxis":"x","y":[3,1,8,9,22,2,3,2,151,7,2,76,11,13,5,62,2,2,65,15,18,2,2,22,63,8,4,7],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{ ...

# %%
box = px.box(df_apps_clean, y='Installs', x='Type', color='Type', notched=True,  points='all', title='How Many Downloads are Paid Apps Giving Up?')
box.update_layout(yaxis=dict(type='log'))
box.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9b84d26b-9d82-42e9-9ec8-9488a5a9ae29" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9b84d26b-9d82-42e9-9ec8-9488a5a9ae29")) {                    Plotly.newPlot(                        "9b84d26b-9d82-42e9-9ec8-9488a5a9ae29",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"Type=%{x}\u003cbr\u003eInstalls=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Free","marker":{"color":"#636efa"},"name":"Free","notched":true,"offsetgroup":"Free","orientation":"v","showlegend":true,"x":["Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free","Free", ...

# %%
df_paid_apps = df_apps_clean[df_apps_clean['Type'] == 'Paid']
box = px.box(df_paid_apps,  x='Category',  y='Revenue_Estimate', title='How Much Can Paid Apps Earn?')
box.update_layout(xaxis_title='Category', yaxis_title='Paid App Ballpark Revenue', xaxis={'categoryorder':'min ascending'}, yaxis=dict(type='log'))
box.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="505ffcd9-16d7-45c3-9e37-eb6ef2e340b5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("505ffcd9-16d7-45c3-9e37-eb6ef2e340b5")) {                    Plotly.newPlot(                        "505ffcd9-16d7-45c3-9e37-eb6ef2e340b5",                        [{"alignmentgroup":"True","hovertemplate":"Category=%{x}\u003cbr\u003eRevenue_Estimate=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["FAMILY","GAME","GAME","FAMILY","FAMILY","FAMILY","SPORTS","GAME","PERSONALIZATION","GAME","GAME","FAMILY","PRODUCTIVITY","WEATHER","FAMILY","FAMILY","PERSONALIZATION","TOOLS","FAMILY","COMMUNICATION","FAMILY","PHOTOGRAPHY","FAMILY","TOOLS","GAME","PERSONALIZATION","GAME","GAME","GAME","FAMILY","GAME","GAME","FAMILY","PERSONALIZATION","PHOTOGRAPHY","GAME","PRODUCTIVITY","PRODUCTIVITY","PRODUCTIVITY","WEATHER","LIFESTYLE","PERSONALIZATION","FAMILY","GAME","GAME","FAMILY","FAMILY","GAME","FINANCE","HEALTH_AND_FITNESS","FAMILY","GAME","FAMILY","COMMUNICATION","GAME","GAME","TOOLS","WEATHER","GAME","PHOTOGRAPHY","GAME","FAMILY","HEALTH_AND_FITNESS","FAMILY","TRAVEL_AND_LOCAL","WEATHER","PERSONALIZATION","FAMILY","GAME","GAME","PHOTOGRAPHY","TOOLS","FAMILY","SPORTS","BUSINESS","FAMILY","GAME","GAME","GAME","FAMILY","GAME","BUSINESS","LIFESTYLE","FAMILY","FAMILY","GAME","FAMILY","PARENTING","TOOLS","GAME","FAMILY","GAME","FAMILY","GAME","PERSONALIZATION","FAMILY","TOOLS","LIFESTYLE","ENTERTAINMENT","MAPS_AND_NAVIGATION","FAMILY","PRODUCTIVITY","GAME","VIDEO_PLAYERS","COMMUNICATION","COMMUNICATION","FAMILY","FAMILY","TOOLS","PERSONALIZATION","PHOTOGRAPHY","FAMILY","VIDEO_PLAYERS","GAME","FAMILY","GAME","MEDICAL","AUTO_AND_VEHICLES","GAME","GAME","GAME","FAMILY","ENTERTAINMENT","FAMILY","FAMILY","EDUCATION","FAMILY","SPORTS","FAMILY","TOOLS","FAMILY","FAMILY","WEATHER","VIDEO_PLAYERS","GAME","FAMILY","MEDICAL","HEALTH_AND_FITNESS","FAMILY","PERSONALIZATION","FAMILY","FAMILY","PERSONALIZATION","SPORTS","GAME","BUSINESS","FAMILY","FAMILY","FOOD_AND_DRINK","HEALTH_AND_FITNESS","HEALTH_AND_FITNESS","FAMILY","TOOLS","PRODUCTIVITY","TOOLS","FAMILY","FAMILY","FAMILY","TOOLS","FAMILY","GAME","FAMILY","FAMILY","FAMILY","GAME","FAMILY","COMMUNICATION","PERSONALIZATION","PERSONALIZATION","DATING","MEDICAL","PERSONALIZATION","FAMILY","PERSONALIZATION","GAME","GAME","TOOLS","FAMILY","PHOTOGRAPHY","TOOLS","MEDICAL","FAMILY","BOOKS_AND_REFERENCE","FAMILY","PHOTOGRAPHY","FOOD_AND_DRINK","ART_AND_DESIGN","FAMILY","FAMILY","MEDICAL","TOOLS","FAMILY","TRAVEL_AND_LOCAL","FAMILY","HEALTH_AND_FITNESS","TOOLS","HEALTH_AND_FITNESS","FAMILY","TOOLS","PRODUCTIVITY","TOOLS","FAMILY","FAMILY","TRAVEL_AND_LOCAL","PERSONALIZATION","FAMILY","ART_AND_DESIGN","HEALTH_AND_FITNESS","TOOLS","FAMILY","FAMILY","BUSINESS","FAMILY","MEDICAL","MEDICAL","FAMILY","FAMILY","SPORTS","SPORTS","FAMILY","GAME","FAMILY","MEDICAL","FAMILY","PHOTOGRAPHY","TOOLS","MEDICAL","MEDICAL","FAMILY","PERSONALIZATION","SPORTS","FAMILY","MEDICAL","GAME","PERSONALIZATION","GAME","MEDICAL","LIFESTYLE","COMMUNICATION","SHOPPING","GAME","FINANCE","TOOLS","MAPS_AND_NAVIGATION","PERSONALIZATION","MAPS_AND_NAVIGATION","FAMILY","SPORTS","HEALTH_AND_FITNESS","GAME","GAME","FAMILY","TOOLS","MEDICAL","FAMILY","FAMILY","FAMILY","MEDICAL","PERSONALIZATION","COMMUNICATION","SPORTS","TRAVEL_AND_LOCAL","PERSONALIZATION","MEDICAL","TOOLS","TOOLS","SPORTS","TOOLS","FAMILY","PERSONALIZATION","PERSONALIZATION","LIFESTYLE","GAME","GAME","FAMILY","COMMUNICATION","TOOLS","TOOLS","FAMILY","PRODUCTIVITY","GAME","PERSONALIZATION","TOOLS","FAMILY","BUSINESS","TRAVEL_AND_LOCAL","LIFESTYLE","PERSONALIZATION","COM ...

# %%
box = px.box(df_paid_apps,  x='Category', y="Price", title='Price per Category')
box.update_layout(xaxis_title='Category', yaxis_title='Paid App Price', xaxis={'categoryorder':'max descending'},  yaxis=dict(type='log'))
box.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7b58ad9d-14e8-4ff3-aa00-cbae5bde6383" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7b58ad9d-14e8-4ff3-aa00-cbae5bde6383")) {                    Plotly.newPlot(                        "7b58ad9d-14e8-4ff3-aa00-cbae5bde6383",                        [{"alignmentgroup":"True","hovertemplate":"Category=%{x}\u003cbr\u003ePrice=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["FAMILY","GAME","GAME","FAMILY","FAMILY","FAMILY","SPORTS","GAME","PERSONALIZATION","GAME","GAME","FAMILY","PRODUCTIVITY","WEATHER","FAMILY","FAMILY","PERSONALIZATION","TOOLS","FAMILY","COMMUNICATION","FAMILY","PHOTOGRAPHY","FAMILY","TOOLS","GAME","PERSONALIZATION","GAME","GAME","GAME","FAMILY","GAME","GAME","FAMILY","PERSONALIZATION","PHOTOGRAPHY","GAME","PRODUCTIVITY","PRODUCTIVITY","PRODUCTIVITY","WEATHER","LIFESTYLE","PERSONALIZATION","FAMILY","GAME","GAME","FAMILY","FAMILY","GAME","FINANCE","HEALTH_AND_FITNESS","FAMILY","GAME","FAMILY","COMMUNICATION","GAME","GAME","TOOLS","WEATHER","GAME","PHOTOGRAPHY","GAME","FAMILY","HEALTH_AND_FITNESS","FAMILY","TRAVEL_AND_LOCAL","WEATHER","PERSONALIZATION","FAMILY","GAME","GAME","PHOTOGRAPHY","TOOLS","FAMILY","